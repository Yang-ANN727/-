# %% [markdown]
# # 00_data_prep.ipynb
#
# 生成或下载示例数据，并做基础清洗。此 notebook 使用 src/data_prep.py 中的合成数据生成函数。

# %%
# 运行合成数据生成并预览
from src.data_prep import generate_synthetic_panel
import pandas as pd
df = generate_synthetic_panel()
df.head()

# %%
# 保存为 data/synthetic_data.csv
import os
os.makedirs('data', exist_ok=True)
df.to_csv('data/synthetic_data.csv', index=False)
print('Saved', 'data/synthetic_data.csv', df.shape)
